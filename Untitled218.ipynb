# %%
#Q1
#class is bascially a blueprint how the object of the class will lool like.
#class has two types attributes and functions.


#object is a instance of the class,which have paticular attribute and functions.

# %%
class Car:
    
    def __init__(self,speed,average):
        self.speed=speed
        self.average=average
    def verify_engine_capacity(self):
        print('the engine is good')

# %%
skoda=Car(40,17)

# %%
skoda.verify_engine_capacity()
# Out:
# the engine is good

# %%
#where class is Car speed and average are attributes,and skoda is object and verify_engine_capacity is function

# %%
#Q2
#Four pillars of oop are 
# Polymorphism,Encapsulation,Abstraction,Inheritance

# %%
#Q3
# __init__ is a special method in oop ,where whatever is present in __init__ is automatically excueted as soon as object of class is made.

# %%
class car:
    
    def __init__(self):
        
        print('hello to our car showroom')

# %%
skoda=car()
# Out:
# hello to our car showroom

# %%
#Q4

#self is a keyword which is generally used in oop,where function of self is to bind the method and object to the current instance, to the class 
#otherwise attributes passed through object is not reached to the class.

# %%
#Q5
# Inheritance is a pillar of oop, where the a another class is created from existing class,to avoid more memory location and 'DRY' principle violation and promote code reuseability.

# %%
#Types of Inheritance
#a multiline inheritance
# multilevel inheritance.
#multi path inheritance

# %%
class product:
    
    def __init__(self):
        pass
class smartphone(product):
    
        print('welcome to our smartphone section')

iphone=smartphone()        
# example of multiline inheritance
# Out:
# welcome to our smartphone section

# %%
class company:
    
    def __init__(self,name):
        self.name=name
    def show(self):
        return self.name
class product:
     def display(self):
            print('this is our product')
class smartphone(company,product):
    pass

# %%
apple=company('apple')

# %%
apple.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 apple.display()
#
# AttributeError: 'company' object has no attribute 'display'
